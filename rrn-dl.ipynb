# %%
# Importing necessary libraries
# !pip install GPUtil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import psutil
import GPUtil
import platform
import tensorflow as tf
import time
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, precision_score, recall_score, f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Print environment information and system details
def print_environment_info():
    print("\nSystem and Package Versions:")
    print(f"Python Version: {platform.python_version()}")
    print(f"TensorFlow Version: {tf.__version__}")
    print(f"Pandas Version: {pd.__version__}")
    print(f"Numpy Version: {np.__version__}")
    print(f"Operating System: {platform.system()} {platform.release()}")

    # CPU information
    print("\nCPU Information:")
    print(f"Physical Cores: {psutil.cpu_count(logical=False)}")
    print(f"Total Cores: {psutil.cpu_count(logical=True)}")
    print(f"Max Frequency: {psutil.cpu_freq().max:.2f}Mhz")
    print(f"Min Frequency: {psutil.cpu_freq().min:.2f}Mhz")
    print(f"Current Frequency: {psutil.cpu_freq().current:.2f}Mhz")
    print(f"Total CPU Usage: {psutil.cpu_percent(interval=1)}%")

    # RAM information
    memory = psutil.virtual_memory()
    print("\nMemory Information (RAM):")
    print(f"Total: {get_size(memory.total)}")
    print(f"Available: {get_size(memory.available)}")
    print(f"Used: {get_size(memory.used)}")
    print(f"Percentage: {memory.percent}%")

    # Disk usage
    disk = psutil.disk_usage('/')
    print("\nDisk Information:")
    print(f"Total Size: {get_size(disk.total)}")
    print(f"Used: {get_size(disk.used)}")
    print(f"Free: {get_size(disk.free)}")
    print(f"Percentage: {disk.percent}%")

    # GPU information
    gpus = GPUtil.getGPUs()
    if len(gpus) > 0:
        print("\nGPU Information:")
        for gpu in gpus:
            print(f"GPU: {gpu.name}")
            print(f"Total Memory: {gpu.memoryTotal}MB")
            print(f"Available Memory: {gpu.memoryFree}MB")
            print(f"Used Memory: {gpu.memoryUsed}MB")
            print(f"GPU Load: {gpu.load * 100}%")
            print(f"Temperature: {gpu.temperature} °C")
    else:
        print("No GPU found.")

# Helper function to convert bytes to GB/MB
def get_size(bytes, suffix="B"):
    factor = 1024
    for unit in ["", "K", "M", "G", "T", "P"]:
        if bytes < factor:
            return f"{bytes:.2f}{unit}{suffix}"
        bytes /= factor

# Callback for better visualization and time tracking
class TrainingProgressCallback(Callback):
    def on_train_begin(self, logs=None):
        self.train_start_time = time.time()
        print("Starting training...\n")

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_start_time = time.time()
        
    def on_epoch_end(self, epoch, logs=None):
        epoch_duration = time.time() - self.epoch_start_time
        print(f"Epoch {epoch + 1}/{self.params['epochs']} - "
              f"{int(epoch_duration * 1000)}ms/epoch - loss: {logs.get('loss'):.4f} - accuracy: {logs.get('accuracy'):.4f} - "
              f"val_loss: {logs.get('val_loss'):.4f} - val_accuracy: {logs.get('val_accuracy'):.4f}\n")
        
    def on_train_end(self, logs=None):
        self.total_train_time = time.time() - self.train_start_time
        print(f"Total Training Time: {self.total_train_time:.2f} seconds\n")

# Data Preprocessing
def load_and_preprocess_data(file_path):
    data = pd.read_csv(file_path)
    
    # Drop irrelevant columns
    columns_to_drop = ['target_dos', 'target_slowite', 'target_malformed', 'target_legitimate', 'target_flood', 'target_bruteforce']
    data_filtered = data.drop(columns=columns_to_drop)

    # Split into features and target
    X = data_filtered.drop(columns=['target']).values
    y = data_filtered['target'].values  # Keep label-encoded targets
    
    # Normalize features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    return X_scaled, y

# Model Architecture - Using RNN instead of LSTM
def create_custom_rnn_model(input_shape):
    model = Sequential([
        SimpleRNN(50, activation='relu', input_shape=input_shape, return_sequences=True),  # Input RNN Layer
        SimpleRNN(50, activation='relu', return_sequences=False),  # First Hidden RNN Layer
        Dropout(0.25),  # Dropout layer
        Dense(40, activation='relu'),  # Dense layer with 40 units
        Dense(25, activation='relu'),  # Dense layer with 25 units
        Dense(6, activation='softmax')  # Output layer with 6 units (softmax activation for multiclass classification)
    ])
    
    # Using AdamW instead of Adam
    optimizer = AdamW(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Model Training and Evaluation
def train_and_evaluate_model(model_fn, X, y, batch_size, epochs, model_params):
    kfold = KFold(n_splits=5, shuffle=True, random_state=42)
    results = []
    fold_no = 1
    
    for train_index, val_index in kfold.split(X):
        X_train, X_val = X[train_index], X[val_index]
        y_train, y_val = y[train_index], y[val_index]
        
        input_shape = (X_train.shape[1], 1)
        X_train_reshaped = X_train.reshape(-1, X_train.shape[1], 1)
        X_val_reshaped = X_val.reshape(-1, X_val.shape[1], 1)
        
        model = model_fn(input_shape=input_shape)
        
        # Early stopping with static patience
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)
        
        # Save the best model
        model_checkpoint = ModelCheckpoint(f"best_model_fold_{fold_no}.keras", monitor='val_loss', save_best_only=True, mode='min')

        # Training the model with custom callback
        progress_callback = TrainingProgressCallback()
        start_train_time = time.time()
        history = model.fit(
            X_train_reshaped, y_train,
            validation_data=(X_val_reshaped, y_val),
            epochs=epochs,
            batch_size=batch_size,
            callbacks=[early_stopping, reduce_lr, model_checkpoint, progress_callback],
            verbose=0
        )
        training_time = time.time() - start_train_time
        
        # Measure testing time
        start_test_time = time.time()
        test_loss, test_accuracy = model.evaluate(X_val_reshaped, y_val)
        testing_time = time.time() - start_test_time
        
        # Predict and calculate metrics
        y_pred_probs = model.predict(X_val_reshaped)
        y_pred_classes = np.argmax(y_pred_probs, axis=1)
        
        precision = precision_score(y_val, y_pred_classes, average='weighted')
        recall = recall_score(y_val, y_pred_classes, average='weighted')
        f1 = f1_score(y_val, y_pred_classes, average='weighted')
        roc_auc = roc_auc_score(y_val, y_pred_probs, multi_class='ovr')
        
        # Print system information
        print_environment_info()
        
        # Save metrics and losses for comparison
        metrics = {
            'fold': fold_no,
            'batch_size': batch_size,
            'epochs': epochs,
            'model_params': model_params,
            'accuracy': test_accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'roc_auc': roc_auc,
            'training_loss': history.history['loss'][-1],
            'validation_loss': history.history['val_loss'][-1],
            'training_time': training_time,
            'testing_time': testing_time
        }
        
        print(f"Fold {fold_no} - Training Time: {training_time:.2f} seconds")
        print(f"Fold {fold_no} - Testing Time: {testing_time:.2f} seconds\n")
        
        # Plot accuracy, loss, confusion matrix, and ROC curve
        plot_and_save_results(metrics, f"Fold_{fold_no}", history, y_val, y_pred_probs, y_pred_classes)
        
        results.append(metrics)
        fold_no += 1
    
    return results

# Plotting and Saving Results
def plot_and_save_results(metrics, model_name, history, y_val, y_pred_probs, y_pred_classes):
    l2_strength = 1e-4
    width_factor = 1
    
    # Plot accuracy and loss over epochs
    if history:
        plt.figure(figsize=(12, 4))
        
        # Accuracy plot
        plt.subplot(1, 2, 1)
        plt.plot(history.history['accuracy'], label='Train Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title(f'{model_name} - Accuracy (L2: {l2_strength}, Width Factor: {width_factor})')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
        
        # Loss plot
        plt.subplot(1, 2, 2)
        plt.plot(history.history['loss'], label='Train Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title(f'{model_name} - Loss (L2: {l2_strength}, Width Factor: {width_factor})')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        
        plt.show()
    
    # Confusion Matrix and ROC Curve
    if y_val is not None and y_pred_probs is not None and y_pred_classes is not None:
        # Confusion Matrix
        cm = confusion_matrix(y_val, y_pred_classes)
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
        plt.title(f'{model_name} - Confusion Matrix (L2: {l2_strength}, Width Factor: {width_factor})')
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.show()
        
        # ROC AUC Score and Curves
        roc_auc = roc_auc_score(y_val, y_pred_probs, multi_class='ovr')
        fpr = {}
        tpr = {}
        
        plt.figure(figsize=(8, 6))
        for i in range(y_pred_probs.shape[1]):
            fpr[i], tpr[i], _ = roc_curve(y_val, y_pred_probs[:, i], pos_label=i)
            plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc:.2f})')
        
        plt.plot([0, 1], [0, 1], 'k--')
        plt.title(f'{model_name} - ROC Curve (L2: {l2_strength}, Width Factor: {width_factor})')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend(loc='best')
        plt.show()

# Main Script Execution
if __name__ == "__main__":
    file_path = '/kaggle/input/dataset/data_MQTT_final.csv'
    X, y = load_and_preprocess_data(file_path)
    
    # Model parameters
    model_params = {
        'width_factor': 1,
        'dropout_rate': 0.3,
        'learning_rate': 0.001,
        'l2_strength': 1e-4
    }
    
    # Train and Evaluate RNN Model with the updated architecture and AdamW optimizer
    custom_training_params = {'batch_size': 250, 'epochs': 100}
    results = train_and_evaluate_model(create_custom_rnn_model, X, y, **custom_training_params, model_params=model_params)
    
    # Save results to CSV
    results_df = pd.DataFrame(results)
    results_df.to_csv('custom_model_metrics_comparison.csv', index=False)
    print("Model metrics comparison saved to 'custom_model_metrics_comparison.csv'.")
    
    # Display the results as a table for comparison
    comparison_df = pd.DataFrame(results)
    print("\nComparison Table:")
    print(comparison_df[['fold', 'batch_size', 'epochs', 'model_params', 'accuracy', 'precision', 'recall', 'f1', 'roc_auc', 'training_loss', 'validation_loss', 'training_time', 'testing_time']])
# Out:
# Collecting GPUtil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: GPUtil
#   Building wheel for GPUtil (setup.py) ... done
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7394 sha256=4150ab39d71e7336e283ebd788344486eb7ac96b8fccf30425a335b4a56c2dd2
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
# Successfully built GPUtil
# Installing collected packages: GPUtil
# Successfully installed GPUtil-1.4.0
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#
━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8833 - loss: 0.3480
# 6205/6205 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
#
# System and Package Versions:
# Python Version: 3.10.14
# TensorFlow Version: 2.16.1
# Pandas Version: 2.2.2
# Numpy Version: 1.26.4
# Operating System: Linux 5.15.154+
#
# CPU Information:
# Physical Cores: 2
# Total Cores: 4
# Max Frequency: 0.00Mhz
# Min Frequency: 0.00Mhz
# Current Frequency: 2000.15Mhz
# Total CPU Usage: 0.5%
#
# Memory Information (RAM):
# Total: 31.36GB
# Available: 28.31GB
# Used: 2.58GB
# Percentage: 9.7%
#
# Disk Information:
# Total Size: 7.87TB
# Used: 5.71TB
# Free: 2.16TB
# Percentage: 72.5%
#
# GPU Information:
# GPU: Tesla T4
# Total Memory: 15360.0MB
# Available Memory: 1023.0MB
# Used Memory: 14073.0MB
# GPU Load: 0.0%
# Temperature: 75.0 °C
# GPU: Tesla T4
# Total Memory: 15360.0MB
# Available Memory: 14993.0MB
# Used Memory: 103.0MB
# GPU Load: 0.0%
# Temperature: 62.0 °C
# Fold 1 - Training Time: 205.43 seconds
# Fold 1 - Testing Time: 20.54 seconds
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Starting training...
#
# Epoch 1/150 - 16992ms/epoch - loss: 0.4789 - accuracy: 0.7680 - val_loss: 0.4046 - val_accuracy: 0.8044
#
# Epoch 2/150 - 9658ms/epoch - loss: 0.4156 - accuracy: 0.7950 - val_loss: 0.3885 - val_accuracy: 0.8197
#
# Epoch 3/150 - 9368ms/epoch - loss: 0.3983 - accuracy: 0.8081 - val_loss: 0.4250 - val_accuracy: 0.7868
#
# Epoch 4/150 - 9476ms/epoch - loss: 0.4019 - accuracy: 0.8065 - val_loss: 0.3894 - val_accuracy: 0.8171
#
# Epoch 5/150 - 9393ms/epoch - loss: 0.3842 - accuracy: 0.8162 - val_loss: 0.3831 - val_accuracy: 0.8213
#
# Epoch 6/150 - 9381ms/epoch - loss: 0.3802 - accuracy: 0.8168 - val_loss: 0.3816 - val_accuracy: 0.8179
#
# Epoch 7/150 - 9418ms/epoch - loss: 0.3777 - accuracy: 0.8192 - val_loss: 0.4160 - val_accuracy: 0.7975
#
# Epoch 8/150 - 9425ms/epoch - loss: 0.3767 - accuracy: 0.8186 - val_loss: 0.3650 - val_accuracy: 0.8304
#
# Epoch 9/150 - 9369ms/epoch - loss: 0.3772 - accuracy: 0.8184 - val_loss: 0.3780 - val_accuracy: 0.8237
#
# Epoch 10/150 - 9492ms/epoch - loss: 0.3751 - accuracy: 0.8188 - val_loss: 0.3912 - val_accuracy: 0.8107
#
# Epoch 11/150 - 9430ms/epoch - loss: 0.3741 - accuracy: 0.8196 - val_loss: 0.3645 - val_accuracy: 0.8175
#
# Epoch 12/150 - 9370ms/epoch - loss: 0.3744 - accuracy: 0.8193 - val_loss: 0.3688 - val_accuracy: 0.8173
#
# Epoch 13/150 - 9375ms/epoch - loss: 0.3756 - accuracy: 0.8189 - val_loss: 0.3669 - val_accuracy: 0.8217
# Epoch 81/150 - 9493ms/epoch - loss: 0.3326 - accuracy: 0.8434 - val_loss: 0.3374 - val_accuracy: 0.8448
#
# Epoch 82/150 - 9374ms/epoch - loss: 0.3324 - accuracy: 0.8431 - val_loss: 0.3330 - val_accuracy: 0.8428
#
# Epoch 83/150 - 9358ms/epoch - loss: 0.3324 - accuracy: 0.8431 - val_loss: 0.3331 - val_accuracy: 0.8425
#
# Epoch 84/150 - 9663ms/epoch - loss: 0.3327 - accuracy: 0.8432 - val_loss: 0.3337 - val_accuracy: 0.8421
#
# Total Training Time: 798.72 seconds
#
# 6205/6205 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8765 - loss: 0.3377
# 6205/6205 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
#
# System and Package Versions:
# Python Version: 3.10.14
# TensorFlow Version: 2.16.1
# Pandas Version: 2.2.2
# Numpy Version: 1.26.4
# Operating System: Linux 5.15.154+
#
# CPU Information:
# Physical Cores: 2
# Total Cores: 4
# Max Frequency: 0.00Mhz
# Min Frequency: 0.00Mhz
# Current Frequency: 2000.15Mhz
# Total CPU Usage: 0.5%
#
# Memory Information (RAM):
# Total: 31.36GB
# Available: 28.04GB
# Used: 2.85GB
# Percentage: 10.6%
#
# Disk Information:
# Total Size: 7.87TB
# Used: 5.71TB
# Free: 2.16TB
# Percentage: 72.5%
#
# GPU Information:
# GPU: Tesla T4
# Total Memory: 15360.0MB
# Available Memory: 1021.0MB
# Used Memory: 14075.0MB
# GPU Load: 0.0%
# Temperature: 73.0 °C
# GPU: Tesla T4
# Total Memory: 15360.0MB
# Available Memory: 14993.0MB
# Used Memory: 103.0MB
# GPU Load: 0.0%
# Temperature: 57.0 °C
# Fold 2 - Training Time: 798.88 seconds
# Fold 2 - Testing Time: 11.51 seconds
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Starting training...
#
# Epoch 1/150 - 17093ms/epoch - loss: 0.4889 - accuracy: 0.7635 - val_loss: 0.4400 - val_accuracy: 0.7739
#
# Epoch 2/150 - 9552ms/epoch - loss: 0.4248 - accuracy: 0.7916 - val_loss: 0.3949 - val_accuracy: 0.8138
#
# Epoch 3/150 - 9382ms/epoch - loss: 0.4216 - accuracy: 0.7928 - val_loss: 0.3982 - val_accuracy: 0.8078
#
# Epoch 4/150 - 9497ms/epoch - loss: 0.4119 - accuracy: 0.8004 - val_loss: 0.3964 - val_accuracy: 0.8000
#
# Epoch 5/150 - 9321ms/epoch - loss: 0.4090 - accuracy: 0.7988 - val_loss: 0.4225 - val_accuracy: 0.7870
#
# Epoch 6/150 - 9423ms/epoch - loss: 0.4099 - accuracy: 0.7968 - val_loss: 0.3886 - val_accuracy: 0.8083
#
# Epoch 7/150 - 9490ms/epoch - loss: 0.4106 - accuracy: 0.8005 - val_loss: 0.4053 - val_accuracy: 0.8003
#
# Epoch 8/150 - 9362ms/epoch - loss: 0.4142 - accuracy: 0.7969 - val_loss: 0.4039 - val_accuracy: 0.7974
#
# Epoch 9/150 - 9402ms/epoch - loss: 0.4035 - accuracy: 0.8047 - val_loss: 0.3754 - val_accuracy: 0.8051
#
# Epoch 10/150 - 9503ms/epoch - loss: 0.4066 - accuracy: 0.8021 - val_loss: 0.4275 - val_accuracy: 0.7846
#
#
# Epoch 34/150 - 9494ms/epoch - loss: 0.3368 - accuracy: 0.8409 - val_loss: 0.3399 - val_accuracy: 0.8408
#
# Epoch 35/150 - 9333ms/epoch - loss: 0.3371 - accuracy: 0.8410 - val_loss: 0.3386 - val_accuracy: 0.8384
#
# Epoch 36/150 - 9384ms/epoch - loss: 0.3362 - accuracy: 0.8415 - val_loss: 0.3382 - val_accuracy: 0.8381
#
# Epoch 37/150 - 9478ms/epoch - loss: 0.3377 - accuracy: 0.8406 - val_loss: 0.3381 - val_accuracy: 0.8387
#
# Epoch 38/150 - 9366ms/epoch - loss: 0.3363 - accuracy: 0.8409 - val_loss: 0.3382 - val_accuracy: 0.8377
#
# Epoch 39/150 - 9281ms/epoch - loss: 0.3369 - accuracy: 0.8406 - val_loss: 0.3373 - val_accuracy: 0.8381
#
# Epoch 40/150 - 9315ms/epoch - loss: 0.3360 - accuracy: 0.8411 - val_loss: 0.3375 - val_accuracy: 0.8382
#
# Total Training Time: 383.91 seconds
#
# 6205/6205 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8754 - loss: 0.3341
# 6205/6205 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
#
# System and Package Versions:
# Python Version: 3.10.14
# TensorFlow Version: 2.16.1
# Pandas Version: 2.2.2
# Numpy Version: 1.26.4
# Operating System: Linux 5.15.154+
#
# CPU Information:
# Physical Cores: 2
# Total Cores: 4
# Max Frequency: 0.00Mhz
# Min Frequency: 0.00Mhz
# Current Frequency: 2000.15Mhz
# Total CPU Usage: 0.7%
#
# Memory Information (RAM):
# Total: 31.36GB
# Available: 27.87GB
# Used: 3.02GB
# Percentage: 11.1%
#
# Disk Information:
# Total Size: 7.87TB
# Used: 5.71TB
# Free: 2.16TB
# Percentage: 72.5%
#
# GPU Information:
# GPU: Tesla T4
# Total Memory: 15360.0MB
# Available Memory: 1021.0MB
# Used Memory: 14075.0MB
# GPU Load: 0.0%
# Temperature: 73.0 °C
# GPU: Tesla T4
# Total Memory: 15360.0MB
# Available Memory: 14993.0MB
# Used Memory: 103.0MB
# GPU Load: 0.0%
# Temperature: 57.0 °C
# Fold 3 - Training Time: 384.05 seconds
# Fold 3 - Testing Time: 11.19 seconds
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Starting training...
#
# Epoch 1/150 - 17813ms/epoch - loss: 0.4909 - accuracy: 0.7605 - val_loss: 0.4217 - val_accuracy: 0.8021
#
# Epoch 2/150 - 9524ms/epoch - loss: 0.4205 - accuracy: 0.7932 - val_loss: 0.4395 - val_accuracy: 0.7832
#
# Epoch 3/150 - 9381ms/epoch - loss: 0.4149 - accuracy: 0.7978 - val_loss: 0.4040 - val_accuracy: 0.8004
#
# Epoch 4/150 - 9385ms/epoch - loss: 0.4159 - accuracy: 0.7954 - val_loss: 0.4154 - val_accuracy: 0.7789
#
# Epoch 5/150 - 9319ms/epoch - loss: 0.4062 - accuracy: 0.8018 - val_loss: 0.4269 - val_accuracy: 0.7820
#
# Epoch 6/150 - 9343ms/epoch - loss: 0.4162 - accuracy: 0.7940 - val_loss: 0.3937 - val_accuracy: 0.8178
#
# Epoch 7/150 - 9439ms/epoch - loss: 0.4164 - accuracy: 0.7934 - val_loss: 0.4200 - val_accuracy: 0.7795
#
# Epoch 8/150 - 9341ms/epoch - loss: 0.4030 - accuracy: 0.8026 - val_loss: 0.3654 - val_accuracy: 0.8368
#
# Epoch 9/150 - 9327ms/epoch - loss: 0.4014 - accuracy: 0.8043 - val_loss: 0.4242 - val_accuracy: 0.7829
#
# Epoch 10/150 - 9324ms/epoch - loss: 0.3864 - accuracy: 0.8131 - val_loss: 0.3780 - val_accuracy: 0.8162
#
# Epoch 11/150 - 9453ms/epoch - loss: 0.3783 - accuracy: 0.8188 - val_loss: 0.4811 - val_accuracy: 0.7642
#
# Epoch 12/150 - 9303ms/epoch - loss: 0.3819 - accuracy: 0.8169 - val_loss: 0.3876 - val_accuracy: 0.8048
#
# Epoch 13/150 - 9258ms/epoch - loss: 0.3752 - accuracy: 0.8189 - val_loss: 0.3708 - val_accuracy: 0.8177
#
# Epoch 14/150 - 9509ms/epoch - loss: 0.3476 - accuracy: 0.8347 - val_loss: 0.3429 - val_accuracy: 0.8363
#
# Epoch 15/150 - 9284ms/epoch - loss: 0.3472 - accuracy: 0.8331 - val_loss: 0.3691 - val_accuracy: 0.8120
#
# Epoch 16/150 - 9397ms/epoch - loss: 0.3510 - accuracy: 0.8319 - val_loss: 0.3410 - val_accuracy: 0.8361
#
# Epoch 17/150 - 9480ms/epoch - loss: 0.3544 - accuracy: 0.8293 - val_loss: 0.3447 - val_accuracy: 0.8360
#
# Epoch 18/150 - 9329ms/epoch - loss: 0.3441 - accuracy: 0.8373 - val_loss: 0.3426 - val_accuracy: 0.8367
#
# Epoch 19/150 - 9311ms/epoch - loss: 0.3413 - accuracy: 0.8379 - val_loss: 0.3415 - val_accuracy: 0.8355
#
# Epoch 20/150 - 9328ms/epoch - loss: 0.3491 - accuracy: 0.8327 - val_loss: 0.3659 - val_accuracy: 0.8227
#
# Epoch 21/150 - 9426ms/epoch - loss: 0.3442 - accuracy: 0.8368 - val_loss: 0.3401 - val_accuracy: 0.8369
#
# Epoch 22/150 - 9260ms/epoch - loss: 0.3440 - accuracy: 0.8357 - val_loss: 0.3468 - val_accuracy: 0.8348
#
# Epoch 23/150 - 9330ms/epoch - loss: 0.3428 - accuracy: 0.8359 - val_loss: 0.3662 - val_accuracy: 0.8233
#
# Epoch 24/150 - 9463ms/epoch - loss: 0.3502 - accuracy: 0.8316 - val_loss: 0.3488 - val_accuracy: 0.8324
#
# Epoch 25/150 - 9325ms/epoch - loss: 0.3401 - accuracy: 0.8379 - val_loss: 0.3661 - val_accuracy: 0.8176
#
# Epoch 26/150 - 9316ms/epoch - loss: 0.3437 - accuracy: 0.8356 - val_loss: 0.3403 - val_accuracy: 0.8376
#
# Epoch 27/150 - 9439ms/epoch - loss: 0.3361 - accuracy: 0.8399 - val_loss: 0.3400 - val_accuracy: 0.8376
#
# Epoch 28/150 - 9359ms/epoch - loss: 0.3364 - accuracy: 0.8394 - val_loss: 0.3382 - val_accuracy: 0.8374
#
# Epoch 29/150 - 9344ms/epoch - loss: 0.3372 - accuracy: 0.8394 - val_loss: 0.3395 - val_accuracy: 0.8373
#
# Epoch 30/150 - 9256ms/epoch - loss: 0.3359 - accuracy: 0.8399 - val_loss: 0.3401 - val_accuracy: 0.8373
#
# Epoch 31/150 - 9422ms/epoch - loss: 0.3359 - accuracy: 0.8400 - val_loss: 0.3382 - val_accuracy: 0.8384
#
# Epoch 32/150 - 9303ms/epoch - loss: 0.3358 - accuracy: 0.8399 - val_loss: 0.3382 - val_accuracy: 0.8380
#
# Epoch 33/150 - 9366ms/epoch - loss: 0.3359 - accuracy: 0.8395 - val_loss: 0.3380 - val_accuracy: 0.8412
#
# Epoch 34/150 - 9447ms/epoch - loss: 0.3356 - accuracy: 0.8402 - val_loss: 0.3385 - val_accuracy: 0.8379
#
# Epoch 35/150 - 9490ms/epoch - loss: 0.3358 - accuracy: 0.8399 - val_loss: 0.3387 - val_accuracy: 0.8379
#
# Epoch 36/150 - 9391ms/epoch - loss: 0.3369 - accuracy: 0.8395 - val_loss: 0.3370 - val_accuracy: 0.8374
#
# Epoch 37/150 - 9332ms/epoch - loss: 0.3365 - accuracy: 0.8397 - val_loss: 0.3402 - val_accuracy: 0.8381
#
# Epoch 38/150 - 9387ms/epoch - loss: 0.3378 - accuracy: 0.8388 - val_loss: 0.3394 - val_accuracy: 0.8378
#
# Epoch 39/150 - 9276ms/epoch - loss: 0.3354 - accuracy: 0.8399 - val_loss: 0.3373 - val_accuracy: 0.8385
#
# Epoch 40/150 - 9378ms/epoch - loss: 0.3352 - accuracy: 0.8402 - val_loss: 0.3361 - val_accuracy: 0.8386
#
# Epoch 41/150 - 9472ms/epoch - loss: 0.3387 - accuracy: 0.8384 - val_loss: 0.3372 - val_accuracy: 0.8381
#
# Epoch 42/150 - 9394ms/epoch - loss: 0.3350 - accuracy: 0.8404 - val_loss: 0.3377 - val_accuracy: 0.8373
#
# Epoch 43/150 - 9398ms/epoch - loss: 0.3359 - accuracy: 0.8398 - val_loss: 0.3356 - val_accuracy: 0.8385
#
# Epoch 44/150 - 9478ms/epoch - loss: 0.3378 - accuracy: 0.8394 - val_loss: 0.3362 - val_accuracy: 0.8387
#
# Epoch 45/150 - 9343ms/epoch - loss: 0.3349 - accuracy: 0.8407 - val_loss: 0.3378 - val_accuracy: 0.8380
#
# Epoch 46/150 - 10421ms/epoch - loss: 0.3394 - accuracy: 0.8381 - val_loss: 0.3375 - val_accuracy: 0.8378
#
# Epoch 47/150 - 9363ms/epoch - loss: 0.3350 - accuracy: 0.8404 - val_loss: 0.3374 - val_accuracy: 0.8372
#
# Epoch 48/150 - 9419ms/epoch - loss: 0.3362 - accuracy: 0.8400 - val_loss: 0.3383 - val_accuracy: 0.8372
#
# Epoch 49/150 - 9369ms/epoch - loss: 0.3347 - accuracy: 0.8405 - val_loss: 0.3376 - val_accuracy: 0.8372
#
# Epoch 50/150 - 9322ms/epoch - loss: 0.3370 - accuracy: 0.8391 - val_loss: 0.3388 - val_accuracy: 0.8376
#
# Epoch 51/150 - 9433ms/epoch - loss: 0.3346 - accuracy: 0.8408 - val_loss: 0.3383 - val_accuracy: 0.8378
#
# Epoch 52/150 - 9348ms/epoch - loss: 0.3367 - accuracy: 0.8394 - val_loss: 0.3431 - val_accuracy: 0.8369
#
# Epoch 53/150 - 9308ms/epoch - loss: 0.3347 - accuracy: 0.8408 - val_loss: 0.3388 - val_accuracy: 0.8379
#
# Total Training Time: 506.33 seconds
#
# 6205/6205 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8880 - loss: 0.3315
# 6205/6205 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
#
# System and Package Versions:
# Python Version: 3.10.14
# TensorFlow Version: 2.16.1
# Pandas Version: 2.2.2
# Numpy Version: 1.26.4
# Operating System: Linux 5.15.154+
#
# CPU Information:
# Physical Cores: 2
# Total Cores: 4
# Max Frequency: 0.00Mhz
# Min Frequency: 0.00Mhz
# Current Frequency: 2000.15Mhz
# Total CPU Usage: 4.3%
#
# Memory Information (RAM):
# Total: 31.36GB
# Available: 27.74GB
# Used: 3.15GB
# Percentage: 11.5%
#
# Disk Information:
# Total Size: 7.87TB
# Used: 5.71TB
# Free: 2.16TB
# Percentage: 72.5%
#
# GPU Information:
# GPU: Tesla T4
# Total Memory: 15360.0MB
# Available Memory: 1021.0MB
# Used Memory: 14075.0MB
# GPU Load: 0.0%
# Temperature: 73.0 °C
# GPU: Tesla T4
# Total Memory: 15360.0MB
# Available Memory: 14993.0MB
# Used Memory: 103.0MB
# GPU Load: 0.0%
# Temperature: 57.0 °C
# Fold 4 - Training Time: 506.48 seconds
# Fold 4 - Testing Time: 11.48 seconds
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Starting training...
#
# Epoch 1/150 - 17307ms/epoch - loss: 0.4837 - accuracy: 0.7649 - val_loss: 0.4123 - val_accuracy: 0.7913
#
# Epoch 2/150 - 9519ms/epoch - loss: 0.4194 - accuracy: 0.7949 - val_loss: 0.3979 - val_accuracy: 0.8033
#
# Epoch 3/150 - 9403ms/epoch - loss: 0.4129 - accuracy: 0.7989 - val_loss: 0.3710 - val_accuracy: 0.8247
#
# Epoch 4/150 - 9496ms/epoch - loss: 0.3934 - accuracy: 0.8121 - val_loss: 0.3705 - val_accuracy: 0.8202
#
# Epoch 5/150 - 9414ms/epoch - loss: 0.3905 - accuracy: 0.8128 - val_loss: 0.3844 - val_accuracy: 0.8091
#
# Epoch 6/150 - 9435ms/epoch - loss: 0.3814 - accuracy: 0.8178 - val_loss: 0.3566 - val_accuracy: 0.8338
#
# Epoch 7/150 - 9384ms/epoch - loss: 0.3815 - accuracy: 0.8171 - val_loss: 0.3679 - val_accuracy: 0.8263
#
# Epoch 8/150 - 9395ms/epoch - loss: 0.3863 - accuracy: 0.8147 - val_loss: 0.3769 - val_accuracy: 0.8193
#
# Epoch 9/150 - 9364ms/epoch - loss: 0.3910 - accuracy: 0.8120 - val_loss: 0.3713 - val_accuracy: 0.8283
#
# Epoch 10/150 - 9399ms/epoch - loss: 0.3972 - accuracy: 0.8074 - val_loss: 0.3995 - val_accuracy: 0.7954
#
# Epoch 11/150 - 9609ms/epoch - loss: 0.4077 - accuracy: 0.8006 - val_loss: 0.4146 - val_accuracy: 0.8000
#
# Epoch 12/150 - 9520ms/epoch - loss: 0.3833 - accuracy: 0.8162 - val_loss: 0.3549 - val_accuracy: 0.8327
#
# Epoch 13/150 - 9423ms/epoch - loss: 0.3622 - accuracy: 0.8296 - val_loss: 0.3422 - val_accuracy: 0.8405
#
# Epoch 14/150 - 9381ms/epoch - loss: 0.3577 - accuracy: 0.8306 - val_loss: 0.3445 - val_accuracy: 0.8395
#
# Epoch 15/150 - 9545ms/epoch - loss: 0.3546 - accuracy: 0.8322 - val_loss: 0.3403 - val_accuracy: 0.8401
#
# Epoch 16/150 - 9333ms/epoch - loss: 0.3493 - accuracy: 0.8348 - val_loss: 0.3362 - val_accuracy: 0.8403
#
# Epoch 17/150 - 9373ms/epoch - loss: 0.3522 - accuracy: 0.8326 - val_loss: 0.3376 - val_accuracy: 0.8405
#
# Epoch 18/150 - 9565ms/epoch - loss: 0.3522 - accuracy: 0.8319 - val_loss: 0.3358 - val_accuracy: 0.8412
#
# Epoch 19/150 - 9345ms/epoch - loss: 0.3636 - accuracy: 0.8242 - val_loss: 0.3521 - val_accuracy: 0.8309
#
# Epoch 20/150 - 9397ms/epoch - loss: 0.3491 - accuracy: 0.8351 - val_loss: 0.3542 - val_accuracy: 0.8282
#
# Epoch 21/150 - 9473ms/epoch - loss: 0.3486 - accuracy: 0.8344 - val_loss: 0.3608 - val_accuracy: 0.8275
#
# Epoch 22/150 - 9378ms/epoch - loss: 0.3442 - accuracy: 0.8374 - val_loss: 0.3459 - val_accuracy: 0.8266
#
# Epoch 23/150 - 9359ms/epoch - loss: 0.3602 - accuracy: 0.8263 - val_loss: 0.3574 - val_accuracy: 0.8289
#
# Epoch 24/150 - 9377ms/epoch - loss: 0.3452 - accuracy: 0.8371 - val_loss: 0.3390 - val_accuracy: 0.8388
#
# Epoch 25/150 - 9432ms/epoch - loss: 0.3402 - accuracy: 0.8394 - val_loss: 0.3401 - val_accuracy: 0.8411
#
# Epoch 26/150 - 9363ms/epoch - loss: 0.3394 - accuracy: 0.8396 - val_loss: 0.3398 - val_accuracy: 0.8392
#
# Epoch 27/150 - 9370ms/epoch - loss: 0.3387 - accuracy: 0.8400 - val_loss: 0.3342 - val_accuracy: 0.8421
#
# Epoch 28/150 - 9481ms/epoch - loss: 0.3390 - accuracy: 0.8397 - val_loss: 0.3379 - val_accuracy: 0.8278
#
# Epoch 29/150 - 9392ms/epoch - loss: 0.3381 - accuracy: 0.8401 - val_loss: 0.3342 - val_accuracy: 0.8411
#
# Epoch 30/150 - 9346ms/epoch - loss: 0.3384 - accuracy: 0.8398 - val_loss: 0.3377 - val_accuracy: 0.8285
#
# Epoch 31/150 - 9578ms/epoch - loss: 0.3378 - accuracy: 0.8403 - val_loss: 0.3329 - val_accuracy: 0.8412
#
# Epoch 32/150 - 9364ms/epoch - loss: 0.3375 - accuracy: 0.8406 - val_loss: 0.3357 - val_accuracy: 0.8416
#
# Epoch 33/150 - 9340ms/epoch - loss: 0.3382 - accuracy: 0.8401 - val_loss: 0.3354 - val_accuracy: 0.8411
#
# Epoch 34/150 - 9360ms/epoch - loss: 0.3372 - accuracy: 0.8407 - val_loss: 0.3364 - val_accuracy: 0.8411
#
# Epoch 35/150 - 9513ms/epoch - loss: 0.3373 - accuracy: 0.8407 - val_loss: 0.3360 - val_accuracy: 0.8416
#
# Epoch 36/150 - 9381ms/epoch - loss: 0.3376 - accuracy: 0.8404 - val_loss: 0.3349 - val_accuracy: 0.8422
#
# Epoch 37/150 - 9441ms/epoch - loss: 0.3381 - accuracy: 0.8402 - val_loss: 0.3360 - val_accuracy: 0.8418
#
# Epoch 38/150 - 9548ms/epoch - loss: 0.3374 - accuracy: 0.8406 - val_loss: 0.3346 - val_accuracy: 0.8422
#
# Epoch 39/150 - 9434ms/epoch - loss: 0.3368 - accuracy: 0.8408 - val_loss: 0.3334 - val_accuracy: 0.8414
#
# Epoch 40/150 - 9420ms/epoch - loss: 0.3366 - accuracy: 0.8410 - val_loss: 0.3346 - val_accuracy: 0.8406
#
# Epoch 41/150 - 9537ms/epoch - loss: 0.3366 - accuracy: 0.8411 - val_loss: 0.3354 - val_accuracy: 0.8413
#
# Total Training Time: 394.58 seconds
#
# 6205/6205 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8729 - loss: 0.3431
# 6205/6205 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
#
# System and Package Versions:
# Python Version: 3.10.14
# TensorFlow Version: 2.16.1
# Pandas Version: 2.2.2
# Numpy Version: 1.26.4
# Operating System: Linux 5.15.154+
#
# CPU Information:
# Physical Cores: 2
# Total Cores: 4
# Max Frequency: 0.00Mhz
# Min Frequency: 0.00Mhz
# Current Frequency: 2000.15Mhz
# Total CPU Usage: 4.8%
#
# Memory Information (RAM):
# Total: 31.36GB
# Available: 27.56GB
# Used: 3.33GB
# Percentage: 12.1%
#
# Disk Information:
# Total Size: 7.87TB
# Used: 5.71TB
# Free: 2.16TB
# Percentage: 72.5%
#
# GPU Information:
# GPU: Tesla T4
# Total Memory: 15360.0MB
# Available Memory: 1019.0MB
# Used Memory: 14077.0MB
# GPU Load: 0.0%
# Temperature: 73.0 °C
# GPU: Tesla T4
# Total Memory: 15360.0MB
# Available Memory: 14993.0MB
# Used Memory: 103.0MB
# GPU Load: 0.0%
# Temperature: 57.0 °C
# Fold 5 - Training Time: 394.72 seconds
# Fold 5 - Testing Time: 11.02 seconds
# Model metrics comparison saved to 'custom_model_metrics_comparison.csv'.
#
# Comparison Table:
#    fold  batch_size  epochs  \
# 0     1         300     150
# 1     2         300     150
# 2     3         300     150
# 3     4         300     150
# 4     5         300     150
#
#                                         model_params  accuracy  precision  \
# 0  {'width_factor': 1, 'dropout_rate': 0.3, 'lear...  0.836792   0.860366
# 1  {'width_factor': 1, 'dropout_rate': 0.3, 'lear...  0.844371   0.862846
# 2  {'width_factor': 1, 'dropout_rate': 0.3, 'lear...  0.844734   0.861575
# 3  {'width_factor': 1, 'dropout_rate': 0.3, 'lear...  0.838508   0.862802
# 4  {'width_factor': 1, 'dropout_rate': 0.3, 'lear...  0.841152   0.860180
#
#      recall        f1   roc_auc  training_loss  validation_loss  \
# 0  0.836792  0.830514  0.980622       0.346825         0.370963
# 1  0.844371  0.838661  0.981232       0.332692         0.333696
# 2  0.844734  0.839532  0.981212       0.336004         0.337461
# 3  0.838508  0.832176  0.981060       0.334704         0.338753
# 4  0.841152  0.835266  0.981249       0.336559         0.335383
#
#    training_time  testing_time
# 0     205.433045     20.543403
# 1     798.875788     11.507370
# 2     384.053945     11.187498
# 3     506.475314     11.483239
# 4     394.720167     11.016024
